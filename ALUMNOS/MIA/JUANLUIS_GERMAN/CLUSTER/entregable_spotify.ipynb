# %% [markdown]
# # EJERCICIO DE CLUSTERING - JUAN LUIS GERMAN SAURA

# %% [markdown]
# #### CARGA DE LIBRERIAS E IMPORTACIÓN DE LOS DATOS

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Yannis\Downloads\genres_v2.csv")
# Out:
# C:\Users\Yannis\AppData\Local\Temp\ipykernel_1348\1520482952.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Yannis\Downloads\genres_v2.csv")

# %% [markdown]
# #### LIMPIEZA Y FILTRADO DE VARIABLES

# %%
display(df.shape)
display(df.head(5))
display(df.describe())
display(df.dtypes)
# Out:
# (42305, 10)
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.831   0.814    -7.364       0.4200        0.0598
# 1         0.719   0.493    -7.230       0.0794        0.4010
# 2         0.850   0.893    -4.783       0.0623        0.0138
# 3         0.476   0.781    -4.710       0.1030        0.0237
# 4         0.798   0.624    -7.668       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.013400    0.0556   0.3890  156.985       124539
# 1          0.000000    0.1180   0.1240  115.080       224427
# 2          0.000004    0.3720   0.0391  218.050        98821
# 3          0.000000    0.1140   0.1750  186.948       123661
# 4          0.000000    0.1660   0.5910  147.988       123298
#        danceability        energy      loudness   speechiness  acousticness  \
# count  42305.000000  42305.000000  42305.000000  42305.000000  42305.000000
# ...

# %%
df.isnull().sum()
# Out:
# danceability        0
# energy              0
# loudness            0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# dtype: int64

# %% [markdown]
# - Se eliminan song_name, unnamed y tittle por ser categóricas y por tener cerca del 50% de sus observaciones nulas
# - Se eliminan id, uri	track_href, analysis_url,type por aportar poco información por ser identificadores<br>
# - Se elimina genre, type y key por ser variable categórica<br>
# - Se elimina time_signature por tener una std cercana a 0 dentro de su propia variable<br>

# %%
df = df.drop(["song_name","Unnamed: 0","title"],axis = 1)
df= df.drop(["id","uri","track_href","analysis_url","genre","type","key","time_signature","mode"],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df = df.drop(["song_name","Unnamed: 0","title"],axis = 1)
#       2 df= df.drop(["id","uri","track_href","analysis_url","genre","type","key","time_signature","mode"],axis = 1)
#
# File c:\Users\Yannis\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %%
#Comprobación tras el borrado
df.head(5)
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.831   0.814    -7.364       0.4200        0.0598
# 1         0.719   0.493    -7.230       0.0794        0.4010
# 2         0.850   0.893    -4.783       0.0623        0.0138
# 3         0.476   0.781    -4.710       0.1030        0.0237
# 4         0.798   0.624    -7.668       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.013400    0.0556   0.3890  156.985       124539
# 1          0.000000    0.1180   0.1240  115.080       224427
# 2          0.000004    0.3720   0.0391  218.050        98821
# 3          0.000000    0.1140   0.1750  186.948       123661
# 4          0.000000    0.1660   0.5910  147.988       123298
